# %%
# Import libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# Importing a dataset 'diabetes.csv'
dataset = pd.read_csv('../datasets/diabetes.csv')

# dataset.head()

dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Split dataset to select features and target variable
feature_columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age']

# Features
X = dataset[feature_columns]

# Target Variable
y = dataset.Outcome

# %%
# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1,shuffle=True)

# %%
# Create Decision Tree Model
model = DecisionTreeClassifier(max_depth=10, criterion='entropy')

# Train model
model.fit(X_train,y_train)

# Form predictions for target variable
y_pred = model.predict(X_test)

# %%
# Calculate accuracy of model
print("Accuracy: ",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.7142857142857143

# %%
# Plot the decision tree
plt.figure(figsize=(35,30))
plot_tree(model,feature_names=feature_columns,class_names=['0','1'],label=all,filled=True,proportion=True,rounded=True,fontsize=6)
# Out:
# [Text(0.4379166666666667, 0.9545454545454546, 'Glucose <= 127.5\n0.926\n100.0%\n[0.659, 0.341]\n0'),
#  Text(0.15666666666666668, 0.8636363636363636, 'BMI <= 26.45\n0.72\n63.7%\n[0.801, 0.199]\n0'),
#  Text(0.05333333333333334, 0.7727272727272727, 'BMI <= 9.1\n0.201\n17.9%\n[0.969, 0.031]\n0'),
#  Text(0.02666666666666667, 0.6818181818181818, 'Pregnancies <= 7.5\n0.918\n1.1%\n[0.667, 0.333]\n0'),
#  Text(0.013333333333333334, 0.5909090909090909, '0.0\n0.7%\n[1.0, 0.0]\n0'),
#  Text(0.04, 0.5909090909090909, '0.0\n0.4%\n[0.0, 1.0]\n1'),
#  Text(0.08, 0.6818181818181818, 'DiabetesPedigreeFunction <= 0.669\n0.088\n16.8%\n[0.989, 0.011]\n0'),
#  Text(0.06666666666666667, 0.5909090909090909, '0.0\n14.0%\n[1.0, 0.0]\n0'),
#  Text(0.09333333333333334, 0.5909090909090909, 'DiabetesPedigreeFunction <= 0.705\n0.353\n2.8%\n[0.933, 0.067]\n0'),
#  Text(0.08, 0.5, '0.0\n0.2%\n[0.0, 1.0]\n1'),
#  Text(0.10666666666666667, 0.5, '0.0\n2.6%\n[1.0, 0.0]\n0'),
# ...

# %%
# Print the number of correct predictions
print("The number of correct predictions are ")
diff=list(y_pred-y_test)
print(diff.count(0)," out of ",len(diff))
# Out:
# The number of correct predictions are
# 165  out of  231
